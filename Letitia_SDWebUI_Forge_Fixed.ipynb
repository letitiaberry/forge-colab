# %%
# 📓 Letitia 修正專用：Forge WebUI 啟動腳本（已修復 requirements 問題）
# ✅ 修正原始 repo 中的 requirements merge conflict
# ✅ 可成功啟動 SD WebUI 並掛載 MeinaMix 模型

# !git clone https://github.com/cagliostrolab/stable-diffusion-webui-forge.git
# %cd stable-diffusion-webui-forge

# 🔧 移除錯誤 requirements_versions.txt 中的 Git 合併衝突標記（如有）
# !sed -i '/^<<<<<<< /d' requirements_versions.txt
# !sed -i '/^=======/d' requirements_versions.txt
# !sed -i '/^>>>>>>> /d' requirements_versions.txt

# 📥 下載 MeinaMix 模型（改用 Hugging Face 直連）
# !mkdir -p models/Stable-diffusion
# !wget -O models/Stable-diffusion/meinamix_meinaV11.safetensors https://huggingface.co/Meina/MeinaMix/resolve/main/meinamix_meinaV11.safetensors

# 📥 下載推薦 VAE 模型
# !mkdir -p models/VAE
# !wget -O models/VAE/vae-ft-mse-840000-ema.safetensors https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema.safetensors

# 🚀 啟動 WebUI（不抓爆掉的 commit hash，自動運行）
# !COMMANDLINE_ARGS="--xformers --enable-insecure-extension-access" python launch.py
